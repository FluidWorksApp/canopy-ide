# %% [markdown]
# # Notebook viewer test
#
# Markdown cells render, code cells show source + outputs.

# %%
total = sum(range(10))
print(f"sum 0..9 = {total}")
# Out:
# sum 0..9 = 45

# %%
import pandas as pd
pd.DataFrame({'a': [1, 2], 'b': [3, 4]})
# Out:
#    a  b
# 0  1  3
# 1  2  4
